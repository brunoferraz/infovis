# %%
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import folium

# %%
# drive.mount("drive")

brasilIO = pd.read_csv("./data/Brasil.io/BrasilIO.csv")
coordenadas = pd.read_csv("./data/coordinates.csv")

statesRawData = brasilIO.query('place_type == "state"')

statesGeoJson = folium.GeoJson("drive/My Drive/Data/Raw/brasil_estados.geojson")

# %%
# m = folium.Map(
#     width = 600, height = 400,
#     location=[-15.77972, -47.92972],
#     zoom_start=3
# )
# folium.TileLayer('Mapbox Bright').add_to(m)
# # statesGeoJson.add_to(m)
# folium.Choropleth(
#     geo_data=statesGeoJson,
#     name='choropleth',
#     data=statesRawData,
#     columns=['State', 'Unemployment'],
#     key_on='feature.id',
#     fill_color='YlGn',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     # legend_name='Unemployment Rate (%)'
# ).add_to(m)

# folium.LayerControl().add_to(m)
# m
